# %%
from sklearn.datasets import load_diabetes
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
x,y= load_diabetes(return_X_y=True)

# %%
y.shape
# Out:
# (442,)

# %%
x.shape
# Out:
# (442, 10)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

lr = LinearRegression()
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)
r2_score(y_test,y_pred)

x_train.shape
# Out:
# (353, 10)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
class GDRegressor:
    def __init__(self,learning_rate,epochs):
        self.lr = learning_rate
        self.epochs = epochs
        self.coef_ = None
        self.intercept_ = None

    def fit(self,x_train,y_train):
        self.intercept_ = 0
        self.coef_ = np.ones(x_train.shape[1])
        for i in range(self.epochs):
            y_hat = np.dot(x_train,self.coef_) + self.intercept_
            slope_intercept = -2 * np.mean(y_train - y_hat)
            self.intercept_ = self.intercept_ - (self.lr * slope_intercept)
            slope_coef = -2 * np.dot((y_train - y_hat),x_train)/x_train.shape[0]
            self.coef_ = self.coef_ - (self.lr * slope_coef)

        # Moved these print statements into the fit method
        print(self.intercept_)
        print(self.coef_)

    def predict(self,x_test):
        return np.dot(x_test,self.coef_) + self.intercept_

# %%
gd = GDRegressor(0.5,1100)
gd.fit(x_train,y_train)
# Out:
# 152.00020262193777
# [  10.81246696 -180.83686999  499.80624643  327.73792089  -42.85297687
#  -120.52478773 -193.96766111  100.79436444  461.98085873   92.90901196]

# %%
y_pred = gd.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.4528045501834096

# %%
(x_train.shape[1])
# Out:
# 10
